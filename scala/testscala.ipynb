// %%
object Geeks 
{
    // Main Method 
    def main(args: Array[String]) 
    {
        // prints Hello World
        println("Hello World!") 
    }
}
// Out:
// defined object Geeks

// %%
object ScalaExample{  
    def main(args:Array[String]){  
        println ("Hello Scala")  
    }  
}
// Out:
// defined object ScalaExample
