// %%
/*Scala program to print your name*/
    object ExPrintName {
       def main(args: Array[String]) {
           println("My name is Mike!")
       }
    }
// Out:
// defined object ExPrintName

// %%
  object ExFindLargest {
       def main(args: Array[String]) {
          var number1=20;
          var number2=30;
          var x = 10;

          if( number1>number2){
             println("Largest number is:" + number1);
          }
          else{
              println("Largest number is:" + number2);
          }
       }
    }
var objectname= new ExFindLargest();
// Out:
// Name: Compile Error
// Message: <console>:39: error: not found: type ExFindLargest
//        var objectname= new ExFindLargest();
//                            ^
//
// StackTrace:

// %%
class Cat
{
var color: String = "black"
var sound: String = "meow meow"
def message()
{
println("color of the cat is  : " + color);
println("what sound does a cat makes : " + sound);
println("End !");
}
}
object Main
{
// Main method
def main(args: Array[String])
{
// creating object to use method of a class.
var ani = new Cat();
ani.message();
}
} 
var objname1= new Cat();
// Out:
// defined class Cat
// defined object Main
// objname1 = Cat@4eb619a
// $line27.$read$$iw$$iw$Cat@4eb619a

// %%
// Out:
// Name: Compile Error
// Message: <console>:4: error: Decimal integer literals may not have a leading zero. (Octal syntax is obsolete.)
// var student1 = new Student("Aman", 20, "Indore", 001)
//                                                  ^
// <console>:5: error: Decimal integer literals may not have a leading zero. (Octal syntax is obsolete.)
// var student2 = new Student("Amit", 30, "Indore", 002)
//                                                  ^
// <console>:6: error: Decimal integer literals may not have a leading zero. (Octal syntax is obsolete.)
// var student3 = new Student("Arun", 22, "Indore", 003)
//                                                  ^
// <console>:7: error: Decimal integer literals may not have a leading zero. (Octal syntax is obsolete.)
// var student4 = new Student("Anamika", 19, "Indore", 004)
//                                                     ^
// ...
