# %%
import os
import sys
os.environ["SPARK_HOME"] = "/usr/spark2.4.3"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
# In below two lines, use /usr/bin/python2.7 if you want to use Python 2
os.environ["PYSPARK_PYTHON"] = "/usr/local/anaconda/bin/python" 
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/local/anaconda/bin/python"
sys.path.insert(0, os.environ["PYLIB"] +"/py4j-0.10.7-src.zip")
sys.path.insert(0, os.environ["PYLIB"] +"/pyspark.zip")

# %%
#from pyspark import SparkContext, SparkConf
#conf = SparkConf().setAppName("appName")
#sc = SparkContext.getOrCreate();
from pyspark.sql import SparkSession
spark = SparkSession.builder
      .master("local[1]")
      .appName("SparkByExamples.com")
      .getOrCreate()  

import pyspark
from pyspark.sql import SparkSession
sc = SparkSession.builder.appName('"textflile"').getOrCreate()
# Out:
#   File "<ipython-input-2-69218fa9fcbf>", line 6
#     .master("local[1]")
#     ^
# IndentationError: unexpected indent

# %%
rdd = sc.read.text("pyspark/sample_data.txt")
print(rdd.take(10))
columns = ["id","first_name","last_name","email","phone","city","country"]
df = sc.createDataFrame(data = rdd, schema = columns)
df.show(truncate=False)
print(sc.version)
# Out:
# [Row(value='id,first_name,last_name,email,phone,city,country'), Row(value='1,Lillian,Slater,purus.Nullam.scelerisque@nonsollicitudin.com,0800 1111,Muridke,Andorra'), Row(value='2,Donna,Pennington,Donec@euaugue.ca,0959 976 7759,Salzwedel,Bermuda'), Row(value='3,Hashim,Sharpe,est@lacus.edu,(011391) 91113,Huntsville,Heard Island and Mcdonald Islands'), Row(value='4,Finn,Chang,consectetuer@eunequepellentesque.org,0800 1111,Stokrooie,Rwanda'), Row(value="5,Harrison,Charles,eleifend@nisi.net,0941 490 8683,Lutsel K'e,Nicaragua"), Row(value='6,Jack,Roth,euismod.urna@orciin.net,055 7666 2472,Pievepelago,Macedonia'), Row(value='7,Yvette,Mullins,enim@tellus.ca,0900 938 9309,Falkirk,Brazil'), Row(value='8,Genevieve,Lamb,vel.sapien.imperdiet@Etiam.net,070 9080 4993,Nieuwkerken-Waas,Cook Islands'), Row(value='9,Nero,Chandler,velit.Sed@Quisque.org,0845 46 45,Alcobendas,Brunei')]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-99427659ad7a> in <module>
#       2 print(rdd.take(10))
#       3 columns = ["id","first_name","last_name","email","phone","city","country"]
# ----> 4 df = sc.createDataFrame(data = rdd, schema = columns)
#       5 df.show(truncate=False)
#       6 print(sc.version)
#
# /usr/spark2.4.3/python/lib/pyspark.zip/pyspark/sql/session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     670         """
#     671         if isinstance(data, DataFrame):
# --> 672             raise TypeError("data is already a DataFrame")
#     673
#     674         if isinstance(schema, basestring):
#
# TypeError: data is already a DataFrame

# %%
type(rdd)
# Out:
# pyspark.rdd.RDD

# %%
import pyspark
from pyspark.sql import SparkSession
