# %%
#Add two numbers in python

# %%
a=20
b=30
print ( a+b )
# Out:
# 50

# %%
d = input("Read first number")
e = input("Read second number")
sum = int(d) + int(e)
print ("Sum of two number is ", sum)
# Out:
# Read first number10
# Read second number20
# Sum of two number is  30
