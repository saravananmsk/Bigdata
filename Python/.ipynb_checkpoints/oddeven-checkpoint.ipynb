# %%
val=int(input("Enter the number\n"))
if val not in range(1,101):
    print("Enter the number between 1 to 100")
        else:
            print(test1)
            if val in range(2,5):
                if (val%2 == 0):
                    print ("Not Weird")
            elif val in range(6,20):
                if (val%2 == 0):
                    print ("Weird")
            elif(val >20 and val <100):
                if (val%2 == 0):
                    print ("Not Weird")
            else:
                  if(val%2 != 0):
                    print("Weird")
