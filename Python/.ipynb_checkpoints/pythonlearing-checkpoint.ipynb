# %%
help()
# Out:
# Welcome to Python 3.6's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.6/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".

# %%
print("this first python program")

# %%
3+5

# %%
3/2

# %%
a=20
if a == 20 then
    print (" the value of a is 20")
end

# %%
help()

# %%
#pthon program
print("This python program")

# %%
print("print")

# %%
a=int(123)
type(a)

# %%
import datetime
str(datetime.datetime.now().date())

# %%
def hello(a):
    print('This to say hello to everyone ')
    return a
    
hello("and good morning")

# %%
a=input("Tell me your name: ")
print("Hello", a)
# Out:
# Tell me your name: Honda
# Hello Honda

# %%
a=6
if (a==6):
    print(" the value of a is " ,a)
# Out:
#  the value of a is  6

# %%
try:
    a=int(input('Enter fist value of a '))
    b=int(input('Enter second value of b'))
    if (a==b):
        print ( 'A is equal to B')
    else:
        print('A is not equal to B')
except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter fist value of a abc
# An error occurred: invalid literal for int() with base 10: 'abc'

# %%
for i in range(1,10):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
i=0
while i<5:
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import sys
dir(sys)
# Out:
# ['__displayhook__',
#  '__doc__',
#  '__excepthook__',
#  '__interactivehook__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  '_clear_type_cache',
#  '_current_frames',
#  '_debugmallocstats',
#  '_getframe',
#  '_git',
#  '_home',
#  '_xoptions',
#  'abiflags',
#  'api_version',
#  'argv',
#  'base_exec_prefix',
#  'base_prefix',
#  'builtin_module_names',
#  'byteorder',
#  'call_tracing',
#  'callstats',
#  'copyright',
#  'displayhook',
#  'dont_write_bytecode',
#  'exc_info',
#  'excepthook',
#  'exec_prefix',
#  'executable',
#  'exit',
#  'flags',
#  'float_info',
#  'float_repr_style',
#  'get_asyncgen_hooks',
#  'get_coroutine_wrapper',
#  'getallocatedblocks',
#  'getcheckinterval',
#  'getdefaultencoding',
#  'getdlopenflags',
#  'getfilesystemencodeerrors',
#  'getfilesystemencoding',
#  'getprofile',
#  'getrecursionlimit',
#  'getrefcount',
#  'getsizeof',
#  'getswitchinterval',
#  'gettrace',
# ...

# %%
class myclass:
    def test1(self):
        print("say hello")
myinstance=myclass()
myinstance.test1()
# Out:
# say hello
